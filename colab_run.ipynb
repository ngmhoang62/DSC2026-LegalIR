# %% [markdown]
# # LegalIR - Google Colab Execution Notebook (EXP-012: Cross-Encoder Reranker)
#
# This notebook runs **EXP-012 (Stage-2 Cross-Encoder Reranker using BAAI/bge-reranker-v2-m3)** on Google Colab using GPU T4/L4/A100 (15GB+ VRAM).

# %%
# Step 1: Mount Google Drive & Set Working Directory
from google.colab import drive
import os
drive.mount('/content/drive')

base_dir = '/content/drive/MyDrive/DSC2026/LegalIR'
# %cd {base_dir}
print(f'Current working directory set to: {os.getcwd()}')

# %%
# Step 2: Create and verify directory structure on Google Drive
os.makedirs(os.path.join(base_dir, 'cache'), exist_ok=True)
os.makedirs(os.path.join(base_dir, 'results'), exist_ok=True)
os.makedirs(os.path.join(base_dir, 'src'), exist_ok=True)
os.makedirs(os.path.join(base_dir, 'public_test_dataset'), exist_ok=True)
print('✅ LegalIR directory structure verified on Google Drive!')

# %%
# Step 3: Install project requirements
# !pip install -r requirements.txt

# %%
# Step 4: Run EXP-012 (Cross-Encoder Stage-2 Reranker with BAAI/bge-reranker-v2-m3)
# Evaluates 5-Fold Stratified Local CV and generates Public Submission zip
# Results saved to: /content/drive/MyDrive/DSC2026/LegalIR/results/reranker/bge_reranker_v2_m3/
# !python src/reranker_exp012.py
